# %%
import super_betcontent
import random
from superdatagenerator import Super2000Data 
import pandas as pd

# %%
bet_params = super_betcontent.bet_params
lottery_dict = super_betcontent.lottery_all
balls_list = super_betcontent.lottery_all[99104][3]

game_content = []
for play in balls_list:
    balls = super_betcontent.all_gameplay[play]
    game_content_single = []
    for i in balls:

        i['id'] = random.randint(0, 100)
        i['moneyunit'] = 1
        i['awardMode'] = 1
        cost = i['moneyunit'] * i['multiple'] * i['num'] * 2

        issue = Super2000Data().select_issue(0, 99104)

        bet_params['gameType'] = lottery_dict[99104][1]
        bet_params['orders'][0]['number'] = issue[0][0]
        bet_params['orders'][0]['issueCode'] = issue[1][0]
        bet_params['amount'] = cost
        bet_params['balls'] = [i]
        
        result = bet_params.copy()

        game_content_single.append(result)
        
        print(game_content_single)

    game_content.append(game_content_single)
# Out:
# [{'gameType': 'tjssc', 'isTrace': 0, 'traceWinStop': 0, 'traceStopValue': -1, 'orders': [{'number': '20210811-023', 'issueCode': 20210811104023, 'multiple': 1}], 'redDiscountAmount': 0, 'amount': 2, 'balls': [{'id': 3, 'ball': '-,-,-,5,-', 'type': 'yixing.dingweidan.fushi', 'moneyunit': 1, 'multiple': 1, 'awardMode': 1, 'num': 1, 'gameType': 'tjssc'}]}]
# ...

# %%
for i in game_content_single:
    print(i)
# Out:
# {'gameType': 'tjssc', 'isTrace': 0, 'traceWinStop': 0, 'traceStopValue': -1, 'orders': [{'number': '20210811-014', 'issueCode': 20210811104014, 'multiple': 1}], 'redDiscountAmount': 0, 'amount': 2, 'balls': [{'id': 99, 'ball': '-,-,0,0,0', 'type': 'housan_2000.zhixuan.fushi', 'moneyunit': 1, 'multiple': 1, 'awardMode': 1, 'num': 1}]}
# {'gameType': 'tjssc', 'isTrace': 0, 'traceWinStop': 0, 'traceStopValue': -1, 'orders': [{'number': '20210811-014', 'issueCode': 20210811104014, 'multiple': 1}], 'redDiscountAmount': 0, 'amount': 2, 'balls': [{'id': 99, 'ball': '-,-,0,0,0', 'type': 'housan_2000.zhixuan.fushi', 'moneyunit': 1, 'multiple': 1, 'awardMode': 1, 'num': 1}]}
# ...

# %%
balls = super_betcontent.all_gameplay['balls_normal5']
game_content_single = []
count = 0
count_dict = {}
for i in balls:
    bet_params['balls'] = [i]
    #print(bet_params, type(bet_params))

    count_dict['NO'] = count
    print(count_dict)
    re = count_dict.copy()


    count += 1

    #print(game_content_single)
    game_content_single.append(re)
#game_content.append(game_content_single)

print(game_content_single)
# Out:
# {'NO': 0}
# {'NO': 1}
# {'NO': 2}
# {'NO': 3}
# {'NO': 4}
# {'NO': 5}
# {'NO': 6}
# {'NO': 7}
# {'NO': 8}
# {'NO': 9}
# {'NO': 10}
# {'NO': 11}
# {'NO': 12}
# {'NO': 13}
# {'NO': 14}
# {'NO': 15}
# {'NO': 16}
# {'NO': 17}
# {'NO': 18}
# {'NO': 19}
# {'NO': 20}
# {'NO': 21}
# {'NO': 22}
# {'NO': 23}
# {'NO': 24}
# {'NO': 25}
# {'NO': 26}
# {'NO': 27}
# {'NO': 28}
# {'NO': 29}
# {'NO': 30}
# {'NO': 31}
# {'NO': 32}
# {'NO': 33}
# {'NO': 34}
# {'NO': 35}
# {'NO': 36}
# {'NO': 37}
# {'NO': 38}
# {'NO': 39}
# {'NO': 40}
# {'NO': 41}
# {'NO': 42}
# {'NO': 43}
# {'NO': 44}
# {'NO': 45}
# {'NO': 46}
# {'NO': 47}
# {'NO': 48}
# {'NO': 49}
# {'NO': 50}
# {'NO': 51}
# {'NO': 52}
# {'NO': 53}
# {'NO': 54}
# {'NO': 55}
# {'NO': 56}
# {'NO': 57}
# {'NO': 58}
# {'NO': 59}
# {'NO': 60}
# {'NO': 61}
# {'NO': 62}
# {'NO': 63}
# {'NO': 64}
# {'NO': 65}
# {'NO': 66}
# {'NO': 67}
# {'NO': 68}
# {'NO': 69}
# {'NO': 70}
# {'NO': 71}
# {'NO': 72}
# {'NO': 73}
# {'NO': 74}
# {'NO': 75}
# {'NO': 76}
# ...

# %%
a =  [
            {
                "id":32,"ball":"0,-,-,-,-","type":"yixing_2000.dingweidan.fushi","moneyunit":"1","multiple":1,"awardMode":1,"num":1
                },
            {
                "id":31,"ball":"0","type":"houer_2000.zuxuan.baodan","moneyunit":"1","multiple":1,"awardMode":2,"num":9
                },
            {
                "id":30,"ball":"1","type":"houer_2000.zuxuan.hezhi","moneyunit":"1","multiple":1,"awardMode":2,"num":1
                },
            {
                "id":29,"ball":"01","type":"houer_2000.zuxuan.danshi","moneyunit":"1","multiple":1,"awardMode":2,"num":1
                },
            {
                "id":28,"ball":"0,1","type":"houer_2000.zuxuan.fushi","moneyunit":"1","multiple":1,"awardMode":2,"num":1
                },
            {
                "id":27,"ball":"0","type":"houer_2000.zhixuan.kuadu","moneyunit":"1","multiple":1,"awardMode":2,"num":10
                },
            {
                "id":26,"ball":"0","type":"houer_2000.zhixuan.hezhi","moneyunit":"1","multiple":1,"awardMode":2,"num":1
                },
            {
                "id":25,"ball":"00","type":"houer_2000.zhixuan.danshi","moneyunit":"1","multiple":1,"awardMode":2,"num":1
                },
            {
                "id":24,"ball":"-,-,-,0,0","type":"houer_2000.zhixuan.fushi","moneyunit":"1","multiple":1,"awardMode":2,"num":1
                },
            {
                "id":23,"ball":"0,1","type":"housan_2000.budingwei.ermabudingwei","moneyunit":"1","multiple":1,"awardMode":1,"num":1
                },
            {
                "id":22,"ball":"0","type":"housan_2000.budingwei.yimabudingwei","moneyunit":"1","multiple":1,"awardMode":1,"num":1
                },
            {
                "id":21,"ball":"012","type":"housan_2000.zuxuan.zuliudanshi","moneyunit":"1","multiple":1,"awardMode":1,"num":1
                },
            {
                "id":20,"ball":"001","type":"housan_2000.zuxuan.zusandanshi","moneyunit":"1","multiple":1,"awardMode":1,"num":1
                },
            {
                "id":19,"ball":"0","type":"housan_2000.zuxuan.baodan","moneyunit":"1","multiple":1,"awardMode":1,"num":54
                },
            {
                "id":18,"ball":"001","type":"housan_2000.zuxuan.hunhezuxuan","moneyunit":"1","multiple":1,"awardMode":1,"num":1
                },
            {
                "id":17,"ball":"0,1,2","type":"housan_2000.zuxuan.zuliu","moneyunit":"1","multiple":1,"awardMode":1,"num":1
                },
            {
                "id":16,"ball":"0,1","type":"housan_2000.zuxuan.zusan","moneyunit":"1","multiple":1,"awardMode":1,"num":2
                },
            {
                "id":15,"ball":"1","type":"housan_2000.zuxuan.hezhi","moneyunit":"1","multiple":1,"awardMode":1,"num":1
                },
            {
                "id":14,"ball":"0","type":"housan_2000.zhixuan.kuadu","moneyunit":"1","multiple":1,"awardMode":1,"num":10
                },
            {
                "id":13,"ball":"0","type":"housan_2000.zhixuan.hezhi","moneyunit":"1","multiple":1,"awardMode":1,"num":1
                },
            {
                "id":12,"ball":"000","type":"housan_2000.zhixuan.danshi","moneyunit":"1","multiple":1,"awardMode":1,"num":1
                },
            {
                "id":11,"ball":"-,-,0,0,0","type":"housan_2000.zhixuan.fushi","moneyunit":"1","multiple":1,"awardMode":1,"num":1
                }
            ]

a_dict = {}
a_list = []

for i in a:
    a_dict['balls'] = [i]
    b =  a_dict.copy()
    a_list.append(b)
    
print(a_list)
# Out:
# [{'balls': [{'id': 32, 'ball': '0,-,-,-,-', 'type': 'yixing_2000.dingweidan.fushi', 'moneyunit': '1', 'multiple': 1, 'awardMode': 1, 'num': 1}]}, {'balls': [{'id': 31, 'ball': '0', 'type': 'houer_2000.zuxuan.baodan', 'moneyunit': '1', 'multiple': 1, 'awardMode': 2, 'num': 9}]}, {'balls': [{'id': 30, 'ball': '1', 'type': 'houer_2000.zuxuan.hezhi', 'moneyunit': '1', 'multiple': 1, 'awardMode': 2, 'num': 1}]}, {'balls': [{'id': 29, 'ball': '01', 'type': 'houer_2000.zuxuan.danshi', 'moneyunit': '1', 'multiple': 1, 'awardMode': 2, 'num': 1}]}, {'balls': [{'id': 28, 'ball': '0,1', 'type': 'houer_2000.zuxuan.fushi', 'moneyunit': '1', 'multiple': 1, 'awardMode': 2, 'num': 1}]}, {'balls': [{'id': 27, 'ball': '0', 'type': 'houer_2000.zhixuan.kuadu', 'moneyunit': '1', 'multiple': 1, 'awardMode': 2, 'num': 10}]}, {'balls': [{'id': 26, 'ball': '0', 'type': 'houer_2000.zhixuan.hezhi', 'moneyunit': '1', 'multiple': 1, 'awardMode': 2, 'num': 1}]}, {'balls': [{'id': 25, 'ball': '00', 'type': 'houer_2
# ...
